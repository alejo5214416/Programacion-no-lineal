# %% [markdown]
# # PROBLEMA DE PROGRAMACION NO LINEAL

# %% [markdown]
# - **Autores:** Johan Sebastian Peña, Sergio Meza Zapata, Hader Castañeda, Alejandro Giraldo Martinez
# - **Fecha:** 16/05/2018
# - **Universidad:** Universidad Autónoma de Manizales

# %% [markdown]
# ## Introduccion

# %% [markdown]
# En el presente documento se demuestra mediante un ejemplo particular, el desarrollo y solución de un Problema de Programación NO Lineal.
#
# Por definición tenemos que un PNL es el proceso de resolución de un sistema de igualdades o desigualdades sujetas a restricciones sobre un conjunto de variables reales desconocidas, con una funcion objetivo a maximizar o minimizar, cuando alguna de las restricciones o la función objetivo **no son lineales**.

# %% [markdown]
# ## Caracteristicas

# %% [markdown]
# - Los problemas de programacion no lineal, tambien son llamados curvilineos, ya que el área que delimita las soluciones factibles en un gráfico se presenta en forma de curva.
#
# - Los problemas no lineales se caracterizan por tener relaciones no lineales, es decir, no existe una relación directa y proporcional entre las variables que intervienen.

# %% [markdown]
# ## Ejemplo 1

# %% [markdown]
# Se requiere cortar y decorar un espejo rectangular de area 40dm$^2$.
#
# Si los adornos a lo largo de los lados horizontales cuestan 16 centavos por decimetro y los de los lados verticales cuestan 25 centavos por decimetro, ¿Cuáles son las dimensiones que **minimizan** el costo total?

# %%
import skimage
# %pylab inline  
import skimage.io as skio

image = skio.imread('figura1.jpg')
plt.imshow(image)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Funcion objetivo

# %% [markdown]
# La función Objetivo está determinada para **MINIMIZAR EL COSTO**

# %% [markdown]
# Min(costo) = $(2x)*16+(2y)*25$
#
# Min(costo) = $32x+50y$

# %% [markdown]
# Se reescribe la función objetivo como se acostumbra en el metodo de multiplicadores de Lagrange:
#
# $$f(x,y)=32x+50y$$

# %% [markdown]
# ### Restricción

# %% [markdown]
# - Por ser x,y medidas del rectangulo: $$x,y\geq 0$$
# - La restricción está dada por el área del espejo
#
# $xy=40$
#
# Por el método de los multiplicadores se acostumbra a tener la restriccion igualada a 0, por lo tanto:
#
# $xy-40=0$
#
# reescribimos:
#
# $$g(x,y)=xy-40$$

# %% [markdown]
# El metodo de multiplicadores de Lagrange porpone:
#
# $$\bigtriangledown \overrightarrow{f}=\lambda \bigtriangledown \overrightarrow{g}$$

# %% [markdown]
# Tenemos que:
# $$(fx,fy)=\lambda (gx,gy)$$
#
# $$(fx,fy)=(\lambda gx,\lambda gy)$$

# %% [markdown]
# Igualamos vectores y despejamos $\lambda$
#
# #### $$fx=\lambda gx \Longleftrightarrow fy=\lambda gy$$
# #### $$\lambda = \frac{fx}{gx} \Longleftrightarrow \lambda = \frac{fy}{gy}$$
#
# Igualando las dos expresiones
#
#
# #### $$\frac{fx}{gx} = \frac{fy}{gy}$$

# %% [markdown]
# - Se realizan las derivadas parciales de cada una de las funciones

# %% [markdown]
# - $f(x,y)=32x+50y$
#
#
# $$\frac{\partial}{\partial x} f(x,y) = 32$$
#
# $$\frac{\partial}{\partial y} f(x,y) = 50$$
#
#
# - $g(x,y)=xy-40$
# $$\frac{\partial}{\partial x} g(x,y) = y$$
#
# $$\frac{\partial}{\partial y} g(x,y) = x$$

# %% [markdown]
# Reemplazamos las derivadas parciales en la relacion anterior:
#
# $$\frac{32}{y} = \frac{50}{x}$$
#
# $$32x=50y$$
#
# Simplificando:
# ### $$16x=25y \Longrightarrow Ecuac. 1$$

# %% [markdown]
# Retomando la Restriccion, tenemos la ecuacion 2 y conformamos un sistema de ecuaciones:
#
# ### $$xy=40 \Longrightarrow  Ecuac. 2$$

# %% [markdown]
# De la Ecuacion 1 despejamos X:
#
#  $$x=\frac{25y}{16} \Longrightarrow Ecuac. 3$$
#
# Sustituimos 3 en 2 y despejamos y:
#
# $$\frac{25y}{16} * y = 40$$
#
# $$\frac{25y^2}{16}=40$$
#
# $$y^2=\frac{(40)(16)}{25}$$
#
# $$y^2=\frac{128}{5}$$
#
# $$y=\sqrt{\frac{128}{5}}$$
#
# # $$y=5.059dm$$

# %% [markdown]
# Reemplazando y en la ecuacion 3:
# $$x=\frac{25(5.059)}{16}$$
#
# # $$x=7.91dm$$

# %%
x = 7.91

# %%
y = 5.059

# %% [markdown]
# Teniendo los valores de x,y obtenemos el Minimo reemplazando en la función Objetivo

# %%
costo = 32*x + 50*y

# %%
costo
# Out:
# 506.07000000000005

# %% [markdown]
# Finalmente tenemos que las dimensiones que minimizan el costo del espejo y que cumplen con las restricciones son:
# ### 7.91 dm (Horizontal)  *  5.059 dm (Vertical) con un Costo minimo de 506.07 centavos

# %% [markdown]
# ## Ejemplo 2

# %% [markdown]
# ###  $$min (x_1-6)^2+(x_2-7)^2$$

# %% [markdown]
# ### Restricciones

# %% [markdown]
# ###  $$g1 \Longrightarrow x_1+x_2\leq6$$
#
# ###  $$g2 \Longrightarrow 2x_1+x_2\leq8$$

# %% [markdown]
# Encontrando Puntos de cortes de cada una de las restricciones g1 y g2:
#
# ### $$g1(x_1,x_2)=(0,6)$$
# ### $$g1(x_1,x_2)=(6,0)$$
# ### $$g2(x_1,x_2)=(0,8)$$
# ### $$g2(x_1,x_2)=(4,0)$$

# %%
g1x1 = np.array ([0, 6])
g1x2 = np.array ([6, 0])
g2x1 = np.array ([0, 4])
g2x2 = np.array ([8, 0])

# %% [markdown]
# La funcion Objetivo hace reperencia a una circunferencia con centro en $(x_1,x_2)=(6,7)$ de radio R

# %%
centrox1=([6])
centrox2=([7])

# %%
fig = plt.figure(figsize=(20,10))

plotg1x1vsg1x2 = plt.plot(g1x1, g1x2, 'og', markersize=20, label=r'$x1 \, vs. \, x2$')
plotlin = plt.plot(g1x1, g1x2, '-r', linewidth=5, label=r'Restriccion g1')

plotg2x1vsg2x2 = plt.plot(g2x1, g2x2, 'or', markersize=20, label=r'$x1 \, vs. \, x2$')
plotlin = plt.plot(g2x1, g2x2, '-b', linewidth=5, label=r'Restriccion g2')

plotcentro = plt.plot(centrox1, centrox2, '*c', markersize=20, label=r'Cetro=Optimo Irrestricto')

plt.legend(loc=0, fontsize=30)
plt.xlim(0,10)
plt.ylim(0,10)

plt.xlabel('x1',fontsize=35)
plt.ylabel('x2',fontsize=35)
plt.title('Gráfica',fontsize=35)

plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.grid(True)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# De a funcion Objetivo sacamos el gradiente para determinar hacia donde se orienta el Optimo.

# %% [markdown]
# ### $$f(x_1,x_2) = (x_1-6)^2+(x_2-7)^2$$
# ### $$ \frac{\partial}{\partial x_1} f(x_1,x_2) = 2(x_1-6) $$
# ### $$ \frac{\partial}{\partial x_2} f(x_1,x_2) = 2(x_2-7) $$

# %% [markdown]
# Igualando la restriccion g1 y g2, se obtiene el punto de interseccion ** $(x_1,x_2)=(2,4)$  **, reemplazando estas coordenadas en las derivadas parciales, obtenemos un vector que nos indica la direccion del incremento del valor Optimo.

# %% [markdown]
# ### Si $x_1=2$ y $x_2=4$
# ### $$2(x_1-6)=-8$$
# ### $$2(x_2-7)=-6$$

# %% [markdown]
# Desde el punto donde se calculó el gradiente, tenemos un desplazamiento en $x_1$ de -8 y para $x_2$ un desplazamiento de -6 unidades. Como el vector resultante se aleja del punto donde se tomó el gradiente, esto nos indica que entre mas nos alejemos el resultado será un maximo.

# %%
fig = plt.figure(figsize=(20,10))
image = skio.imread('gradiente.jpg')
plt.imshow(image)

# %% [markdown]
# De acuerdo al problema, se requiere minimizar la funcion objetivo, por lo cual no debemos alejarnos del centro de la circunferencia dentro de la refion factible y se evalua el punto $(x_1,x_2)=(2,4)$ en la funcion objetivo para tener el valor optimo que minimiza el problema y a su ve encontraremos el radio minimo de la circunferencia

# %% [markdown]
# ## $$f(x_1,x_2) = (x_1-6)^2+(x_2-7)^2$$

# %%
minimo = (2-6)**2+(4-7)**2

# %%
opt = (2,4)

# %%
r=sqrt(25)

# %%
print('Minimo = ',minimo)
print('Punto para Optimo = ',opt)
print('Radio minimo = ',r)
# Out:
# Minimo =  25
# Punto para Optimo =  (2, 4)
# Radio minimo =  5.0
